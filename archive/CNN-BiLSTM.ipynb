# %%
#import necessary libraries

#Visualization
import matplotlib.pyplot as plt
import seaborn as sns

#Data handling and Linear algebra
import pandas as pd
import numpy as np

#Manipulating data and Model building
import tensorflow as tf

#Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
url = "https://www.sidc.be/silso/DATA/SN_m_tot_V2.0.csv"
data = pd.read_csv(url, sep=';', header=None,
                   names=['year', 'month', 'decimal_year', 'sunspot_number', 
                          'std_dev', 'observations', 'indicator'])
data.head()
# Out:
#    year  month  decimal_year  sunspot_number  std_dev  observations  indicator
# 0  1749      1      1749.042            96.7     -1.0            -1          1
# 1  1749      2      1749.123           104.3     -1.0            -1          1
# 2  1749      3      1749.204           116.7     -1.0            -1          1
# 3  1749      4      1749.288            92.8     -1.0            -1          1
# 4  1749      5      1749.371           141.7     -1.0            -1          1

# %%
data.tail()
# Out:
#       year  month  decimal_year  sunspot_number  std_dev  observations  \
# 3324  2026      1      2026.042           112.5     22.1           666
# 3325  2026      2      2026.122            78.2     14.2           757
# 3326  2026      3      2026.204            85.9     12.7          1202
# 3327  2026      4      2026.286            79.3     11.4          1159
# 3328  2026      5      2026.371           101.4     14.8          1130
#
#       indicator
# 3324          0
# 3325          0
# 3326          0
# 3327          0
# 3328          0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3329 entries, 0 to 3328
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            3329 non-null   int64
#  1   month           3329 non-null   int64
#  2   decimal_year    3329 non-null   float64
#  3   sunspot_number  3329 non-null   float64
#  4   std_dev         3329 non-null   float64
#  5   observations    3329 non-null   int64
#  6   indicator       3329 non-null   int64
# dtypes: float64(3), int64(4)
# memory usage: 182.2 KB

# %%
#Last column--> Sunspots data
sunspots = data.iloc[:,3]
sunspots.values
# Out:
# array([ 96.7, 104.3, 116.7, ...,  85.9,  79.3, 101.4])

# %%
#Visualize the data
plt.figure(figsize=(28,6))
plt.plot(sunspots)
plt.ylabel(data.columns[-1],fontsize=12,color='m')
plt.xlabel("Months from Jan 1749 to Jan 2021",fontsize=12,color='m')
plt.title("Sunspots Data",fontsize=18,color='r',weight='bold')
plt.show()

# %%
'''Approx 11 years cycle ---> approx 132 months cycle'''
plt.figure(figsize=(28,6))
plt.plot(sunspots)            # The whole data
plt.plot(sunspots[:72])       # Data from 1749, actual cycles started from 1755 --> 6 years means 72 months
plt.plot(sunspots[72:72+132]) # Showing the first cycle
plt.plot(sunspots[-13:])      # Displaying the current cycle
plt.ylabel(data.columns[-1], fontsize = 12, color = 'm')
plt.xlabel("Months from Jan 1749 to Jan 2021", fontsize = 12, color = 'm')
plt.title("Understanding the Sunspots data", fontsize = 18, color = 'r', weight = 'bold')
plt.legend(["Full data", "Before 1755 - The first cycle", "The first cycle", "After 2019 - The currect cycle"], fontsize = 12)
plt.show()

# %%
#Visualize the variation in the data distribution along with the outliers in the time series data
plt.figure(figsize=(15,6))
plt.subplot(2,1,1)
sns.distplot(sunspots)
plt.title("Variation in the data distribution",fontsize=15,color='r',weight='bold')
plt.subplot(2,1,2)
sns.boxplot(x=sunspots)
plt.title("Boxplot of data",fontsize=15,color='r',weight='bold')
plt.tight_layout()
plt.show()

# %%
#Helper function: Training data generation
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    series = series[:, np.newaxis]                                # Adding new dimension to the series array in the position where np.newaxis is written
    ds = tf.data.Dataset.from_tensor_slices(series)               # In order to use window of tensorflow convert numpy array to tensor
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True) # Creating window for generating sequence (yet not seperating it with the future values) - LSTM
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))          # Flatten a dataset of batches into a dataset of their elements
    ds = ds.shuffle(shuffle_buffer)                               # To reduce the variance and making sure that the model remain general and less overfits
    ds = ds.map(lambda w: (w[:-1], w[-1]))                        # In a window, last value is the future value that our model needs to learn and predict while testing it
    return ds.batch(batch_size).prefetch(1)                       # Prefetch one batch of data and make sure that there is always one ready

# %%
# Forecast would work in the same way where we provide the sequence and the output will be predicted by the model
def model_forecast(model, series, window_size):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size))
    ds = ds.batch(batch_size).prefetch(1)
    forecast = model.predict(ds)  # To predict
    return forecast

# %%
# Preparing the data
series = data['sunspot_number'].values
time = data.index.values 

# Splitting the data into train and test
split_time = int(len(series)*0.9)          # 90% of the original data is for training
time_train = time[:split_time]
x_train = series[:split_time]
time_valid = time[split_time:]
x_valid = series[split_time:]
print(f"There are {len(x_train)} training samples and {len(x_valid)} validation samples.")

# Parameters
delta = 1                      # Huber loss
window_size = 60               # For dataset
batch_size = 64  #显存爆了batch_size = 145               # For dataset
shuffle_buffer_size= 900       # Shuffling the dataset randomly
epochs = 100                   # For optimal learning rate
train_epochs = epochs + 100    # Training epochs
momentum_sgd = 0.9             # For optimizer
# Out:
# There are 2996 training samples and 333 validation samples.

# %%
# To avoid clutter from old models and layers (in case of re-running the notebook without reset and resestart)
tf.keras.backend.clear_session()

# To produce same sequence of results each time the code runs
tf.random.set_seed(42)
np.random.seed(42)

# Calling the window_dataset function to generate the training data
train_set = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)

# Building the model
model = tf.keras.models.Sequential([
    
    # 1. 一维因果卷积层（CNN层）保持不动
    tf.keras.layers.Conv1D(
        filters=64,  #132, 
        kernel_size=4,
        strides=1, 
        padding="causal", 
        activation="relu",
        input_shape=[None, 1]
    ),
    
    # 2. 【核心修改】将第一层 LSTM 改为双向 BiLSTM
    # 因为后面还要接一层 BiLSTM，所以 return_sequences 依然要设为 True
    tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(128, return_sequences=True)#原本256
    ), 
    
    # 3. 【核心修改】将第二层 LSTM 也改为双向 BiLSTM
    # 后面直接对接全连接层（Dense），所以 return_sequences 设为 False
    tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(64, return_sequences=False)#132
    ),
    
    # 4. 后续的全连接层和缩放层完全保留你原先的设计
    tf.keras.layers.Dense(64, activation="relu"),
    tf.keras.layers.Dense(10, activation="relu"),
    tf.keras.layers.Dense(1),
    
    # 缩放层，将输出映射回太阳黑子数据的实际量级
    tf.keras.layers.Lambda(lambda x: x * 400)        
])

# Display this model summary
model.summary()

# Using callbacks - Learning rate scheduler to find the optimal value to be used in the final model
lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-8 * 10**(epoch / 20), verbose = 0) # lr --> starting lr * 10^(0/20), starting lr * 10^(1/20), so on..

# Stochastic Gradient Desect as the optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=1e-8, momentum=momentum_sgd)
model.compile(loss=tf.keras.losses.Huber(delta),
              optimizer=optimizer,
              metrics=["mae"])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, None, 64)          320
#
#  bidirectional (Bidirectiona  (None, None, 256)        197632
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 128)              164352
#  nal)
#
#  dense (Dense)               (None, 64)                8256
#
#  dense_1 (Dense)             (None, 10)                650
#
#  dense_2 (Dense)             (None, 1)                 11
#
#  lambda (Lambda)             (None, 1)                 0
#
# =================================================================
# Total params: 371,221
# Trainable params: 371,221
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train
#        3.98107171e-07, 4.46683592e-07, 5.01187234e-07, 5.62341325e-07,
#        6.30957344e-07, 7.07945784e-07, 7.94328235e-07, 8.91250938e-07,
#        1.00000000e-06, 1.12201845e-06, 1.25892541e-06, 1.41253754e-06,
#        1.58489319e-06, 1.77827941e-06, 1.99526231e-06, 2.23872114e-06,
#        2.51188643e-06, 2.81838293e-06, 3.16227766e-06, 3.54813389e-06,
#        3.98107171e-06, 4.46683592e-06, 5.01187234e-06, 5.62341325e-06,
#        6.30957344e-06, 7.07945784e-06, 7.94328235e-06, 8.91250938e-06,
#        1.00000000e-05, 1.12201845e-05, 1.25892541e-05, 1.41253754e-05,
#        1.58489319e-05, 1.77827941e-05, 1.99526231e-05, 2.23872114e-05,
#        2.51188643e-05, 2.81838293e-05, 3.16227766e-05, 3.54813389e-05,
#        3.98107171e-05, 4.46683592e-05, 5.01187234e-05, 5.62341325e-05,
#        6.30957344e-05, 7.07945784e-05, 7.94328235e-05, 8.91250938e-05,
#        1.00000000e-04, 1.12201845e-04, 1.25892541e-04, 1.41253754e-04,
#        1.58489319e-04, 1.77827941e-04, 1.99526231e-04, 2.23872114e-04,
#        2.51188643e-04, 2.81838293e-04, 3.16227766e-04, 3.54813389e-04,
#        3.98107171e-04, 4.46683592e-04, 5.01187234e-04, 5.62341325e-04,
#        6.30957344e-04, 7.07945784e-04, 7.94328235e-04, 8.91250938e-04])

# %%
# Fetch the optimum learning rate
min_loss = min(history.history['loss'])
idx_min_loss = history.history['loss'].index(min_loss)
opt_lr = lrs[idx_min_loss]
first = str(round(float(str(opt_lr).split('e')[0])))
second = str(opt_lr).split('e')[-1]
final = [first, second]
x = "e".join(final)
x = float(x)
print(f"Optimal Learning Rate was --> {x}.")
# Out:
# Optimal Learning Rate was --> 3e-06.

# %%
# Plot the output of Losses vs Learning Rates
fig = plt.figure(figsize=(15, 6))
plt.semilogx(lrs, history.history["loss"]) # Learning rates are increasing exponentially and hence for an omptimal sized plot we use semilogx plot
plt.grid(True, ls="--")
plt.plot(opt_lr,min_loss, color = 'r', marker = 'x', markersize = 7)
plt.title(f"Looking for Optimum Learning Rate", color = 'm', fontsize = 15)
plt.ylabel("Losses", fontsize = 13, color = 'g')
plt.xlabel("Learining Rates", fontsize = 13, color = 'g')
plt.annotate(f"lr = {x}", (opt_lr,min_loss+2), (opt_lr+0.05e-5, min_loss+15), arrowprops = dict(facecolor ='k', width = 2, headwidth = 8), fontsize = 12)
plt.show()

# %%
# Using the same steps to build the model but now with the optimal learning rate to train it
tf.keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

# 🎯 【关键修改】同步换成 CNN + 瘦身版 BiLSTM 架构
model = tf.keras.models.Sequential([
    # 1. 一维因果卷积层
    tf.keras.layers.Conv1D(
        filters=64,             # 保持和第一阶段一致的瘦身尺寸（64）
        kernel_size=4,
        strides=1, 
        padding="causal", 
        activation="relu",
        input_shape=[None, 1]
    ),
    
    # 2. 第一层双向 BiLSTM（记得开启 return_sequences）
    tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(128, return_sequences=True) # 保持瘦身后的 128
    ), 
    
    # 3. 第二层双向 BiLSTM（对接 Dense，return_sequences 为 False）
    tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(64, return_sequences=False) # 保持瘦身后的 64
    ),
    
    # 4. 全连接层与缩放层
    tf.keras.layers.Dense(64, activation="relu"),
    tf.keras.layers.Dense(10, activation="relu"),
    tf.keras.layers.Dense(1),
    tf.keras.layers.Lambda(lambda x: x * 400)
])

# 这里会自动使用上面寻找并赋值好的 opt_lr 变量
optimizer = tf.keras.optimizers.SGD(learning_rate=opt_lr, momentum=momentum_sgd)

model.compile(loss=tf.keras.losses.Huber(delta),
              optimizer=optimizer,
              metrics=["mae"])

# 正式大训 200 轮
history = model.fit(train_set, epochs=train_epochs)
# Out:
# Epoch 1/200
# 46/46 [==============================] - 4s 27ms/step - loss: 30.8970 - mae: 31.3927
# Epoch 2/200
# 46/46 [==============================] - 1s 27ms/step - loss: 19.9250 - mae: 20.4185
# Epoch 3/200
# 46/46 [==============================] - 1s 26ms/step - loss: 18.5887 - mae: 19.0812
# Epoch 4/200
# 46/46 [==============================] - 1s 26ms/step - loss: 18.7017 - mae: 19.1951
# Epoch 5/200
# 46/46 [==============================] - 1s 26ms/step - loss: 17.8049 - mae: 18.2956
# Epoch 6/200
# 46/46 [==============================] - 1s 26ms/step - loss: 18.6436 - mae: 19.1368
# Epoch 7/200
# 46/46 [==============================] - 1s 26ms/step - loss: 17.8335 - mae: 18.3253
# Epoch 8/200
# 46/46 [==============================] - 1s 26ms/step - loss: 17.5640 - mae: 18.0557
# Epoch 9/200
# 46/46 [==============================] - 1s 26ms/step - loss: 17.2501 - mae: 17.7426
# Epoch 10/200
# 46/46 [==============================] - 1s 26ms/step - loss: 17.5444 - mae: 18.0381
# Epoch 11/200
# 46/46 [==============================] - 1s 28ms/step - loss: 17.2854 - mae: 17.7762
# Epoch 12/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.9463 - mae: 17.4390
# Epoch 13/200
# 46/46 [==============================] - 1s 27ms/step - loss: 17.1809 - mae: 17.6723
# Epoch 14/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.9729 - mae: 17.4631
# Epoch 15/200
# 46/46 [==============================] - 1s 27ms/step - loss: 17.1375 - mae: 17.6289
# Epoch 16/200
# 46/46 [==============================] - 1s 26ms/step - loss: 17.1291 - mae: 17.6213
# Epoch 17/200
# 46/46 [==============================] - 1s 26ms/step - loss: 17.1321 - mae: 17.6250
# Epoch 18/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.8432 - mae: 17.3353
# Epoch 19/200
# 46/46 [==============================] - 1s 27ms/step - loss: 17.2566 - mae: 17.7482
# Epoch 20/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.8671 - mae: 17.3588
# Epoch 21/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.8667 - mae: 17.3585
# Epoch 22/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.8658 - mae: 17.3592
# Epoch 23/200
# 46/46 [==============================] - 1s 26ms/step - loss: 17.2493 - mae: 17.7428
# Epoch 24/200
# 46/46 [==============================] - 1s 26ms/step - loss: 17.0749 - mae: 17.5668
# Epoch 25/200
# 46/46 [==============================] - 1s 25ms/step - loss: 16.9975 - mae: 17.4902
# Epoch 26/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.7329 - mae: 17.2244
# Epoch 27/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.6734 - mae: 17.1642
# Epoch 28/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.9216 - mae: 17.4132
# Epoch 29/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.5129 - mae: 17.0031
# Epoch 30/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.4249 - mae: 16.9161
# Epoch 31/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.5712 - mae: 17.0643
# Epoch 32/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.5819 - mae: 17.0739
# Epoch 33/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.3694 - mae: 16.8609
# Epoch 34/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.1836 - mae: 16.6747
# Epoch 35/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.3008 - mae: 16.7925
# Epoch 36/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.2801 - mae: 16.7708
# Epoch 37/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.3966 - mae: 16.8886
# Epoch 38/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.2125 - mae: 16.7032
# Epoch 39/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.3645 - mae: 16.8556
# Epoch 40/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.1513 - mae: 16.6423
# Epoch 41/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.7354 - mae: 17.2262
# Epoch 42/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.5636 - mae: 17.0538
# Epoch 43/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.4051 - mae: 16.8951
# Epoch 44/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.9421 - mae: 17.4319
# Epoch 45/200
# 46/46 [==============================] - 1s 25ms/step - loss: 17.2727 - mae: 17.7643
# Epoch 46/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.2141 - mae: 16.7050
# Epoch 47/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.9734 - mae: 16.4641
# Epoch 48/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.3220 - mae: 16.8133
# Epoch 49/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.1285 - mae: 16.6180
# Epoch 50/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.1771 - mae: 16.6691
# Epoch 51/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.4180 - mae: 16.9096
# Epoch 52/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.3752 - mae: 16.8669
# Epoch 53/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.6916 - mae: 17.1841
# Epoch 54/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.3160 - mae: 16.8078
# Epoch 55/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.9491 - mae: 16.4392
# Epoch 56/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.0476 - mae: 16.5386
# Epoch 57/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.4296 - mae: 16.9204
# Epoch 58/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.2550 - mae: 16.7459
# Epoch 59/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.2343 - mae: 16.7263
# Epoch 60/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.8928 - mae: 16.3834
# Epoch 61/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.3306 - mae: 16.8226
# Epoch 62/200
# 46/46 [==============================] - 1s 27ms/step - loss: 15.8432 - mae: 16.3339
# Epoch 63/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.9085 - mae: 16.3985
# Epoch 64/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.9026 - mae: 16.3934
# Epoch 65/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.9134 - mae: 16.4031
# Epoch 66/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.1336 - mae: 16.6242
# Epoch 67/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.9273 - mae: 16.4194
# Epoch 68/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.8877 - mae: 16.3773
# Epoch 69/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.8222 - mae: 16.3115
# Epoch 70/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.9047 - mae: 16.3942
# Epoch 71/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.8860 - mae: 16.3758
# Epoch 72/200
# 46/46 [==============================] - 1s 27ms/step - loss: 15.6543 - mae: 16.1434
# Epoch 73/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.0864 - mae: 16.5775
# Epoch 74/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.7719 - mae: 16.2611
# Epoch 75/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.5454 - mae: 16.0346
# Epoch 76/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.6012 - mae: 16.0919
# Epoch 77/200
# 46/46 [==============================] - 1s 27ms/step - loss: 15.6358 - mae: 16.1252
# Epoch 78/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.0704 - mae: 16.5604
# Epoch 79/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.0124 - mae: 16.5016
# Epoch 80/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.1430 - mae: 16.6336
# Epoch 81/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.2003 - mae: 16.6903
# Epoch 82/200
# 46/46 [==============================] - 1s 27ms/step - loss: 15.7751 - mae: 16.2656
# Epoch 83/200
# 46/46 [==============================] - 1s 27ms/step - loss: 15.7552 - mae: 16.2451
# Epoch 84/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.8134 - mae: 16.3027
# Epoch 85/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.4867 - mae: 15.9767
# Epoch 86/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.8849 - mae: 16.3743
# Epoch 87/200
# 46/46 [==============================] - 1s 27ms/step - loss: 15.6762 - mae: 16.1668
# Epoch 88/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.6081 - mae: 16.0967
# Epoch 89/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.9230 - mae: 16.4133
# Epoch 90/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.7673 - mae: 16.2576
# Epoch 91/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.7665 - mae: 16.2571
# Epoch 92/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.7574 - mae: 16.2480
# Epoch 93/200
# 46/46 [==============================] - 1s 27ms/step - loss: 15.6723 - mae: 16.1620
# Epoch 94/200
# 46/46 [==============================] - 1s 27ms/step - loss: 15.7303 - mae: 16.2222
# Epoch 95/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.4832 - mae: 15.9724
# Epoch 96/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.7057 - mae: 16.1957
# Epoch 97/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.6831 - mae: 16.1731
# Epoch 98/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.1061 - mae: 16.5961
# Epoch 99/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.6555 - mae: 16.1465
# Epoch 100/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.3953 - mae: 15.8846
# Epoch 101/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.4195 - mae: 15.9095
# Epoch 102/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.8594 - mae: 16.3514
# Epoch 103/200
# 46/46 [==============================] - 1s 27ms/step - loss: 15.6794 - mae: 16.1704
# Epoch 104/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.3491 - mae: 15.8385
# Epoch 105/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.4383 - mae: 15.9286
# Epoch 106/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.4480 - mae: 15.9378
# Epoch 107/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.3136 - mae: 15.8039
# Epoch 108/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.3869 - mae: 15.8783
# Epoch 109/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.5686 - mae: 16.0588
# Epoch 110/200
# 46/46 [==============================] - 1s 27ms/step - loss: 15.6955 - mae: 16.1861
# Epoch 111/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.6807 - mae: 16.1698
# Epoch 112/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.9090 - mae: 16.4006
# Epoch 113/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.4220 - mae: 15.9117
# Epoch 114/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.4764 - mae: 15.9660
# Epoch 115/200
# 46/46 [==============================] - 1s 27ms/step - loss: 15.8561 - mae: 16.3467
# Epoch 116/200
# 46/46 [==============================] - 1s 26ms/step - loss: 16.3772 - mae: 16.8671
# Epoch 117/200
# 46/46 [==============================] - 1s 27ms/step - loss: 15.4578 - mae: 15.9470
# Epoch 118/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.2975 - mae: 15.7860
# Epoch 119/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.5382 - mae: 16.0279
# Epoch 120/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.4650 - mae: 15.9555
# Epoch 121/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.3635 - mae: 15.8533
# Epoch 122/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.6241 - mae: 16.1154
# Epoch 123/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.3616 - mae: 15.8520
# Epoch 124/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.5701 - mae: 16.0593
# Epoch 125/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.7622 - mae: 16.2538
# Epoch 126/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.2025 - mae: 15.6930
# Epoch 127/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.1473 - mae: 15.6365
# Epoch 128/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.1697 - mae: 15.6595
# Epoch 129/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.3607 - mae: 15.8492
# Epoch 130/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.4383 - mae: 15.9266
# Epoch 131/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.5605 - mae: 16.0504
# Epoch 132/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.2104 - mae: 15.6994
# Epoch 133/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.0771 - mae: 15.5671
# Epoch 134/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.5997 - mae: 16.0885
# Epoch 135/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.4368 - mae: 15.9266
# Epoch 136/200
# 46/46 [==============================] - 1s 27ms/step - loss: 15.0755 - mae: 15.5629
# Epoch 137/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.1774 - mae: 15.6666
# Epoch 138/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.0955 - mae: 15.5852
# Epoch 139/200
# 46/46 [==============================] - 1s 27ms/step - loss: 15.5486 - mae: 16.0386
# Epoch 140/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.4677 - mae: 15.9577
# Epoch 141/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.9834 - mae: 15.4722
# Epoch 142/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.0678 - mae: 15.5552
# Epoch 143/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.3071 - mae: 15.7974
# Epoch 144/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.0743 - mae: 15.5635
# Epoch 145/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.3136 - mae: 15.8033
# Epoch 146/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.1671 - mae: 15.6569
# Epoch 147/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.8447 - mae: 15.3322
# Epoch 148/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.2861 - mae: 15.7754
# Epoch 149/200
# 46/46 [==============================] - 1s 27ms/step - loss: 15.1757 - mae: 15.6648
# Epoch 150/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.8893 - mae: 15.3770
# Epoch 151/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.4943 - mae: 15.9864
# Epoch 152/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.8393 - mae: 15.3278
# Epoch 153/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.9856 - mae: 15.4747
# Epoch 154/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.0474 - mae: 15.5349
# Epoch 155/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.4356 - mae: 15.9250
# Epoch 156/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.9555 - mae: 15.4424
# Epoch 157/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.3515 - mae: 15.8418
# Epoch 158/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.8696 - mae: 15.3575
# Epoch 159/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.1314 - mae: 15.6219
# Epoch 160/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.8198 - mae: 15.3086
# Epoch 161/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.1122 - mae: 15.6012
# Epoch 162/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.9817 - mae: 15.4714
# Epoch 163/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.9679 - mae: 15.4583
# Epoch 164/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.2577 - mae: 15.7475
# Epoch 165/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.0113 - mae: 15.5001
# Epoch 166/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.7397 - mae: 15.2286
# Epoch 167/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.8802 - mae: 15.3693
# Epoch 168/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.7835 - mae: 15.2708
# Epoch 169/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.7570 - mae: 15.2442
# Epoch 170/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.8796 - mae: 15.3669
# Epoch 171/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.9465 - mae: 15.4364
# Epoch 172/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.7806 - mae: 15.2693
# Epoch 173/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.7771 - mae: 15.2643
# Epoch 174/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.8309 - mae: 15.3190
# Epoch 175/200
# 46/46 [==============================] - 1s 27ms/step - loss: 14.6458 - mae: 15.1360
# Epoch 176/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.8359 - mae: 15.3264
# Epoch 177/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.0345 - mae: 15.5223
# Epoch 178/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.7124 - mae: 15.2001
# Epoch 179/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.0443 - mae: 15.5341
# Epoch 180/200
# 46/46 [==============================] - 1s 25ms/step - loss: 15.0449 - mae: 15.5351
# Epoch 181/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.8525 - mae: 15.3430
# Epoch 182/200
# 46/46 [==============================] - 1s 26ms/step - loss: 15.3253 - mae: 15.8148
# Epoch 183/200
# 46/46 [==============================] - 1s 25ms/step - loss: 14.7468 - mae: 15.2347
# Epoch 184/200
# 46/46 [==============================] - 1s 27ms/step - loss: 14.6114 - mae: 15.0979
# Epoch 185/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.7111 - mae: 15.1992
# Epoch 186/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.9567 - mae: 15.4471
# Epoch 187/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.6182 - mae: 15.1067
# Epoch 188/200
# 46/46 [==============================] - 1s 27ms/step - loss: 14.6592 - mae: 15.1455
# Epoch 189/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.9502 - mae: 15.4395
# Epoch 190/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.6508 - mae: 15.1410
# Epoch 191/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.6901 - mae: 15.1769
# Epoch 192/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.7232 - mae: 15.2117
# Epoch 193/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.7219 - mae: 15.2103
# Epoch 194/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.4656 - mae: 14.9537
# Epoch 195/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.5710 - mae: 15.0582
# Epoch 196/200
# 46/46 [==============================] - 1s 27ms/step - loss: 14.6148 - mae: 15.1026
# Epoch 197/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.7297 - mae: 15.2168
# Epoch 198/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.6821 - mae: 15.1700
# Epoch 199/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.7929 - mae: 15.2826
# Epoch 200/200
# 46/46 [==============================] - 1s 26ms/step - loss: 14.5799 - mae: 15.0671

# %%
# Fetch the MAE and Huber Loss from the history
mae=history.history['mae']
loss=history.history['loss']

# Plot MAE and Huber Loss
fig = plt.figure(figsize=(15, 6))
plt.plot(mae, 'r')
plt.plot(loss, 'b')
plt.title('MAE and Loss')
plt.xlabel("Epochs")
plt.legend(["MAE", "Loss"])

# %%
# Call the model_forecast here and display the plots of validation and prediction
rnn_forecast = model_forecast(model, series[:, np.newaxis], window_size)
rnn_forecast = rnn_forecast[split_time - window_size:-1, 0]  # rnn_forecast[-328:-1, 0]

# Plots
plt.figure(figsize=(15, 6))
plt.plot(time_valid, x_valid)
plt.plot(time_valid, rnn_forecast)
plt.title("")
plt.legend(["Validation Data", "Predicted Data"])
plt.show()
# Out:
# 52/52 [==============================] - 1s 13ms/step

# %%
# Validation MAE
val_mae=tf.keras.metrics.mae(x_valid, rnn_forecast).numpy()
print(f"MAE on the validation data:- {val_mae}")
# Out:
# MAE on the validation data:- 14.866718292236328

# %% [markdown]
# ## 结果展示

# %%
# %% [markdown]
# ## 结果展示

# %%
# 1. 确保模型已经训练好，对整个序列进行预测
full_forecast = model_forecast(model, series[:, np.newaxis], window_size)   # shape: (len(series)-window_size, 1)
full_forecast = full_forecast[:, 0]   # 变成一维

# 2. 计算原始数据中 2024-01 和 2026-04 的索引
data['date'] = pd.to_datetime(data[['year', 'month']].assign(day=1))
start_date = pd.Timestamp('2024-01-01')
end_date   = pd.Timestamp('2026-04-01')
start_idx = data[data['date'] == start_date].index[0]
end_idx   = data[data['date'] == end_date].index[0]

# 3. 预测值的索引偏移
forecast_start = start_idx - window_size
forecast_end   = end_idx - window_size

# 检查索引是否有效
if forecast_start < 0 or forecast_end >= len(full_forecast):
    raise ValueError(f"索引超出范围: forecast_start={forecast_start}, forecast_end={forecast_end}, full_forecast长度={len(full_forecast)}")

# 4. 正确截取 2024-2026 的真实值与预测值（此时变量正式被定义和赋值！）
y_true_2024_2026 = data['sunspot_number'].iloc[start_idx:end_idx+1].values
y_pred_2024_2026 = full_forecast[forecast_start:forecast_end+1]

# 5. 【移到这里】检查模型预测值是否恒定
print("预测的唯一值有：", np.unique(y_pred_2024_2026)) 

# 6. 可视化
plt.figure(figsize=(12,5))
plt.plot(y_true_2024_2026, label='Actual')
plt.plot(y_pred_2024_2026, label='Predicted')
plt.legend()
plt.title('Sunspots: 2024-01 to 2026-04')
plt.show()

# 7. 计算标量 MAE 和 MSE
y_true_flat = y_true_2024_2026.flatten()
y_pred_flat = y_pred_2024_2026.flatten()

mae_scalar = np.mean(np.abs(y_true_flat - y_pred_flat))
mse_scalar = np.mean((y_true_flat - y_pred_flat) ** 2)

print(f"MAE (2024-2026): {mae_scalar:.4f}")
print(f"MSE (2024-2026): {mse_scalar:.4f}")
# Out:
# 52/52 [==============================] - 1s 13ms/step
# 预测的唯一值有： [ 99.21205  104.16131  109.48434  116.28722  118.38018  118.816376
#  123.788025 127.007675 127.913795 129.44423  130.98895  133.25116
#  135.13704  136.55711  141.29617  141.68565  142.71031  149.2185
#  150.21306  151.58868  151.63228  155.5044   156.47629  159.4811
#  161.6406   163.31517  163.54372  172.37082 ]
# MAE (2024-2026): 18.7629
# MSE (2024-2026): 659.7210
