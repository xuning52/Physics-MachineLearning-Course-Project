# %%
#import necessary libraries

#Tensorflow Board
import datetime

#Visualization
import matplotlib.pyplot as plt
import seaborn as sns

#Data handling and Linear algebra
import pandas as pd
import numpy as np

#Manipulating data and Model building
import tensorflow as tf

#Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
url = "https://www.sidc.be/silso/DATA/SN_m_tot_V2.0.csv"
data = pd.read_csv(url, sep=';', header=None,
                   names=['year', 'month', 'decimal_year', 'sunspot_number', 
                          'std_dev', 'observations', 'indicator'])
data.head()
# Out:
#    year  month  decimal_year  sunspot_number  std_dev  observations  indicator
# 0  1749      1      1749.042            96.7     -1.0            -1          1
# 1  1749      2      1749.123           104.3     -1.0            -1          1
# 2  1749      3      1749.204           116.7     -1.0            -1          1
# 3  1749      4      1749.288            92.8     -1.0            -1          1
# 4  1749      5      1749.371           141.7     -1.0            -1          1

# %%
data.tail()
# Out:
#       year  month  decimal_year  sunspot_number  std_dev  observations  \
# 3324  2026      1      2026.042           112.5     22.1           666
# 3325  2026      2      2026.122            78.2     14.2           757
# 3326  2026      3      2026.204            85.9     12.7          1202
# 3327  2026      4      2026.286            79.3     11.4          1159
# 3328  2026      5      2026.371           101.4     14.8          1130
#
#       indicator
# 3324          0
# 3325          0
# 3326          0
# 3327          0
# 3328          0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3329 entries, 0 to 3328
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            3329 non-null   int64
#  1   month           3329 non-null   int64
#  2   decimal_year    3329 non-null   float64
#  3   sunspot_number  3329 non-null   float64
#  4   std_dev         3329 non-null   float64
#  5   observations    3329 non-null   int64
#  6   indicator       3329 non-null   int64
# dtypes: float64(3), int64(4)
# memory usage: 182.2 KB

# %%
#Last column--> Sunspots data
sunspots = data.iloc[:,3]
sunspots.values
# Out:
# array([ 96.7, 104.3, 116.7, ...,  85.9,  79.3, 101.4])

# %%
#Visualize the data
plt.figure(figsize=(28,6))
plt.plot(sunspots)
plt.ylabel(data.columns[-1],fontsize=12,color='m')
plt.xlabel("Months from Jan 1749 to Jan 2021",fontsize=12,color='m')
plt.title("Sunspots Data",fontsize=18,color='r',weight='bold')
plt.show()

# %%
'''Approx 11 years cycle ---> approx 132 months cycle'''
plt.figure(figsize=(28,6))
plt.plot(sunspots)            # The whole data
plt.plot(sunspots[:72])       # Data from 1749, actual cycles started from 1755 --> 6 years means 72 months
plt.plot(sunspots[72:72+132]) # Showing the first cycle
plt.plot(sunspots[-13:])      # Displaying the current cycle
plt.ylabel(data.columns[-1], fontsize = 12, color = 'm')
plt.xlabel("Months from Jan 1749 to Jan 2021", fontsize = 12, color = 'm')
plt.title("Understanding the Sunspots data", fontsize = 18, color = 'r', weight = 'bold')
plt.legend(["Full data", "Before 1755 - The first cycle", "The first cycle", "After 2019 - The currect cycle"], fontsize = 12)
plt.show()

# %%
#Visualize the variation in the data distribution along with the outliers in the time series data
plt.figure(figsize=(15,6))
plt.subplot(2,1,1)
sns.distplot(sunspots)
plt.title("Variation in the data distribution",fontsize=15,color='r',weight='bold')
plt.subplot(2,1,2)
sns.boxplot(x=sunspots)
plt.title("Boxplot of data",fontsize=15,color='r',weight='bold')
plt.tight_layout()
plt.show()

# %%
#Helper function: Training data generation
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    series = series[:, np.newaxis]                                # Adding new dimension to the series array in the position where np.newaxis is written
    ds = tf.data.Dataset.from_tensor_slices(series)               # In order to use window of tensorflow convert numpy array to tensor
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True) # Creating window for generating sequence (yet not seperating it with the future values) - LSTM
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))          # Flatten a dataset of batches into a dataset of their elements
    ds = ds.shuffle(shuffle_buffer)                               # To reduce the variance and making sure that the model remain general and less overfits
    ds = ds.map(lambda w: (w[:-1], w[-1]))                        # In a window, last value is the future value that our model needs to learn and predict while testing it
    return ds.batch(batch_size).prefetch(1)                       # Prefetch one batch of data and make sure that there is always one ready

# %%
# Forecast would work in the same way where we provide the sequence and the output will be predicted by the model
def model_forecast(model, series, window_size):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size))
    ds = ds.batch(batch_size).prefetch(1)
    forecast = model.predict(ds)  # To predict
    return forecast

# %%
# Preparing the data
series = data['sunspot_number'].values
time = data.index.values 

# Splitting the data into train and test
split_time = int(len(series)*0.9)          # 90% of the original data is for training
time_train = time[:split_time]
x_train = series[:split_time]
time_valid = time[split_time:]
x_valid = series[split_time:]
print(f"There are {len(x_train)} training samples and {len(x_valid)} validation samples.")

# Parameters
delta = 1                      # Huber loss
window_size = 60               # For dataset
batch_size = 64  #显存爆了batch_size = 145               # For dataset
shuffle_buffer_size= 900       # Shuffling the dataset randomly
epochs = 100                   # For optimal learning rate
train_epochs = epochs + 100    # Training epochs
momentum_sgd = 0.9             # For optimizer
# Out:
# There are 2996 training samples and 333 validation samples.

# %%
# To avoid clutter from old models and layers (in case of re-running the notebook without reset and resestart)
tf.keras.backend.clear_session()

# To produce same sequence of results each time the code runs
tf.random.set_seed(42)
np.random.seed(42)

# Calling the window_dataset function to generate the training data
train_set = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)

# Building the model
model = tf.keras.models.Sequential([
    
    # 1. 一维因果卷积层（CNN层）保持不动
    tf.keras.layers.Conv1D(
        filters=64,  #132, 
        kernel_size=4,
        strides=1, 
        padding="causal", 
        activation="relu",
        input_shape=[None, 1]
    ),
    
    # 2. 【核心修改】将第一层 LSTM 改为双向 BiLSTM
    # 因为后面还要接一层 BiLSTM，所以 return_sequences 依然要设为 True
    tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(128, return_sequences=True)#原本256
    ), 
    
    # 3. 【核心修改】将第二层 LSTM 也改为双向 BiLSTM
    # 后面直接对接全连接层（Dense），所以 return_sequences 设为 False
    tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(64, return_sequences=False)#132
    ),
    
    # 4. 后续的全连接层和缩放层完全保留原先的设计
    tf.keras.layers.Dense(64, activation="relu"),
    tf.keras.layers.Dense(10, activation="relu"),
    tf.keras.layers.Dense(1),
    
    # 缩放层，将输出映射回太阳黑子数据的实际量级
    tf.keras.layers.Lambda(lambda x: x * 400)        
])

# Display this model summary
model.summary()

# Using callbacks - Learning rate scheduler to find the optimal value to be used in the final model
lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-8 * 10**(epoch / 20), verbose = 0) # lr --> starting lr * 10^(0/20), starting lr * 10^(1/20), so on..

# Stochastic Gradient Desect as the optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=1e-8, momentum=momentum_sgd)
model.compile(loss=tf.keras.losses.Huber(delta),
              optimizer=optimizer,
              metrics=["mae"])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, None, 64)          320
#
#  bidirectional (Bidirectiona  (None, None, 256)        197632
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 128)              164352
#  nal)
#
#  dense (Dense)               (None, 64)                8256
#
#  dense_1 (Dense)             (None, 10)                650
#
#  dense_2 (Dense)             (None, 1)                 11
#
#  lambda (Lambda)             (None, 1)                 0
#
# =================================================================
# Total params: 371,221
# Trainable params: 371,221
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train
# 46/46 [==============================] - 1s 25ms/step - loss: 56.6390 - mae: 57.1370 - lr: 7.0795e-04
# Epoch 99/100
# 46/46 [==============================] - 1s 25ms/step - loss: 59.3460 - mae: 59.8442 - lr: 7.9433e-04
# Epoch 100/100
# 46/46 [==============================] - 1s 25ms/step - loss: 60.7071 - mae: 61.2056 - lr: 8.9125e-04

# %%
# Learning rates used above
lrs = 1e-8 * (10**(np.arange(epochs)/20))
lrs
# Out:
# array([1.00000000e-08, 1.12201845e-08, 1.25892541e-08, 1.41253754e-08,
#        1.58489319e-08, 1.77827941e-08, 1.99526231e-08, 2.23872114e-08,
#        2.51188643e-08, 2.81838293e-08, 3.16227766e-08, 3.54813389e-08,
#        3.98107171e-08, 4.46683592e-08, 5.01187234e-08, 5.62341325e-08,
#        6.30957344e-08, 7.07945784e-08, 7.94328235e-08, 8.91250938e-08,
#        1.00000000e-07, 1.12201845e-07, 1.25892541e-07, 1.41253754e-07,
#        1.58489319e-07, 1.77827941e-07, 1.99526231e-07, 2.23872114e-07,
#        2.51188643e-07, 2.81838293e-07, 3.16227766e-07, 3.54813389e-07,
#        3.98107171e-07, 4.46683592e-07, 5.01187234e-07, 5.62341325e-07,
#        6.30957344e-07, 7.07945784e-07, 7.94328235e-07, 8.91250938e-07,
#        1.00000000e-06, 1.12201845e-06, 1.25892541e-06, 1.41253754e-06,
#        1.58489319e-06, 1.77827941e-06, 1.99526231e-06, 2.23872114e-06,
#        2.51188643e-06, 2.81838293e-06, 3.16227766e-06, 3.54813389e-06,
#        3.98107171e-06, 4.46683592e-06, 5.01187234e-06, 5.62341325e-06,
#        6.30957344e-06, 7.07945784e-06, 7.94328235e-06, 8.91250938e-06,
#        1.00000000e-05, 1.12201845e-05, 1.25892541e-05, 1.41253754e-05,
#        1.58489319e-05, 1.77827941e-05, 1.99526231e-05, 2.23872114e-05,
#        2.51188643e-05, 2.81838293e-05, 3.16227766e-05, 3.54813389e-05,
#        3.98107171e-05, 4.46683592e-05, 5.01187234e-05, 5.62341325e-05,
#        6.30957344e-05, 7.07945784e-05, 7.94328235e-05, 8.91250938e-05,
#        1.00000000e-04, 1.12201845e-04, 1.25892541e-04, 1.41253754e-04,
#        1.58489319e-04, 1.77827941e-04, 1.99526231e-04, 2.23872114e-04,
#        2.51188643e-04, 2.81838293e-04, 3.16227766e-04, 3.54813389e-04,
#        3.98107171e-04, 4.46683592e-04, 5.01187234e-04, 5.62341325e-04,
#        6.30957344e-04, 7.07945784e-04, 7.94328235e-04, 8.91250938e-04])

# %%
# Fetch the optimum learning rate
min_loss = min(history.history['loss'])
idx_min_loss = history.history['loss'].index(min_loss)
opt_lr = lrs[idx_min_loss]
first = str(round(float(str(opt_lr).split('e')[0])))
second = str(opt_lr).split('e')[-1]
final = [first, second]
x = "e".join(final)
x = float(x)
print(f"Optimal Learning Rate was --> {x}.")
# Out:
# Optimal Learning Rate was --> 2e-06.

# %%
# Plot the output of Losses vs Learning Rates
fig = plt.figure(figsize=(15, 6))
plt.semilogx(lrs, history.history["loss"]) # Learning rates are increasing exponentially and hence for an omptimal sized plot we use semilogx plot
plt.grid(True, ls="--")
plt.plot(opt_lr,min_loss, color = 'r', marker = 'x', markersize = 7)
plt.title(f"Looking for Optimum Learning Rate", color = 'm', fontsize = 15)
plt.ylabel("Losses", fontsize = 13, color = 'g')
plt.xlabel("Learining Rates", fontsize = 13, color = 'g')
plt.annotate(f"lr = {x}", (opt_lr,min_loss+2), (opt_lr+0.05e-5, min_loss+15), arrowprops = dict(facecolor ='k', width = 2, headwidth = 8), fontsize = 12)
plt.show()

# %%
# Using the same steps to build the model but now with the optimal learning rate to train it
tf.keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

# 【关键修改】同步换成 CNN + 瘦身版 BiLSTM 架构
model = tf.keras.models.Sequential([
    # 1. 一维因果卷积层
    tf.keras.layers.Conv1D(
        filters=64,             # 保持和第一阶段一致的瘦身尺寸（64）
        kernel_size=4,
        strides=1, 
        padding="causal", 
        activation="relu",
        input_shape=[None, 1]
    ),
    
    # 2. 第一层双向 BiLSTM（记得开启 return_sequences）
    tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(128, return_sequences=True) # 保持瘦身后的 128
    ), 
    
    # 3. 第二层双向 BiLSTM（对接 Dense，return_sequences 为 False）
    tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(64, return_sequences=False) # 保持瘦身后的 64
    ),
    
    # 4. 全连接层与缩放层
    tf.keras.layers.Dense(64, activation="relu"),
    tf.keras.layers.Dense(10, activation="relu"),
    tf.keras.layers.Dense(1),
    tf.keras.layers.Lambda(lambda x: x * 400)
])

# 这里会自动使用上面寻找并赋值好的 opt_lr 变量
optimizer = tf.keras.optimizers.SGD(learning_rate=opt_lr, momentum=momentum_sgd)

model.compile(loss=tf.keras.losses.Huber(delta),
              optimizer=optimizer,
              metrics=["mae"])

# 【新增 TensorBoard 配置】
# 自动生成类似 logs/fit/20260602-233400 的文件夹
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(
    log_dir=log_dir, 
    histogram_freq=1,   # 每个 epoch 记录一次权重直方图
    write_graph=True    # 记录模型网络拓扑结构图
)

# 正式大训 200 轮（通过 callbacks 参数把面板召唤出来）
history = model.fit(
    train_set, 
    epochs=train_epochs, 
    callbacks=[tensorboard_callback]  # 加上这个参数
)
# Out:
# Epoch 1/200
# 46/46 [==============================] - 4s 29ms/step - loss: 33.3135 - mae: 33.8092
# Epoch 2/200
# 46/46 [==============================] - 1s 27ms/step - loss: 22.5337 - mae: 23.0277
# Epoch 3/200
# 46/46 [==============================] - 1s 27ms/step - loss: 20.3427 - mae: 20.8357
# Epoch 4/200
# 46/46 [==============================] - 1s 27ms/step - loss: 19.8874 - mae: 20.3817
# Epoch 5/200
# 46/46 [==============================] - 1s 27ms/step - loss: 19.2384 - mae: 19.7311
# Epoch 6/200
# 46/46 [==============================] - 1s 27ms/step - loss: 18.8333 - mae: 19.3273
# Epoch 7/200
# 46/46 [==============================] - 1s 28ms/step - loss: 18.5488 - mae: 19.0404
# Epoch 8/200
# 46/46 [==============================] - 1s 27ms/step - loss: 18.2691 - mae: 18.7616
# Epoch 9/200
# 46/46 [==============================] - 1s 28ms/step - loss: 17.8803 - mae: 18.3714
# Epoch 10/200
# 46/46 [==============================] - 1s 27ms/step - loss: 18.1583 - mae: 18.6505
200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.8539 - mae: 17.3449
# Epoch 50/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.8783 - mae: 17.3669
# Epoch 51/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.8581 - mae: 17.3482
# Epoch 52/200
# 46/46 [==============================] - 1s 27ms/step - loss: 17.1906 - mae: 17.6812
# Epoch 53/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.8133 - mae: 17.3032
# Epoch 54/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.7969 - mae: 17.2862
# Epoch 55/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.6831 - mae: 17.1739
# Epoch 56/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.4450 - mae: 16.9335
# Epoch 57/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.6997 - mae: 17.1878
# Epoch 58/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.5071 - mae: 16.9967
# Epoch 59/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.4726 - mae: 16.9623
# Epoch 60/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.4448 - mae: 16.9345
# Epoch 61/200
# 46/46 [==============================] - 1s 27ms/step - loss: 17.2458 - mae: 17.7345
# Epoch 62/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.3108 - mae: 16.7992
# Epoch 63/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.5858 - mae: 17.0746
# Epoch 64/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.7076 - mae: 17.1975
# Epoch 65/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.2731 - mae: 16.7623
# Epoch 66/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.5018 - mae: 16.9909
# Epoch 67/200
# 46/46 [==============================] - 1s 27ms/step - loss: 17.2678 - mae: 17.7583
# Epoch 68/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.4113 - mae: 16.9023
# Epoch 69/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.5745 - mae: 17.0645
# Epoch 70/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.4003 - mae: 16.8897
# Epoch 71/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.8828 - mae: 17.3723
# Epoch 72/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.4668 - mae: 16.9556
# Epoch 73/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.4116 - mae: 16.8990
# Epoch 74/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.4963 - mae: 16.9865
# Epoch 75/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.3955 - mae: 16.8849
# Epoch 76/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.3445 - mae: 16.8331
# Epoch 77/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.2403 - mae: 16.7299
# Epoch 78/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.4326 - mae: 16.9226
# Epoch 79/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.4978 - mae: 16.9863
# Epoch 80/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.4948 - mae: 16.9842
# Epoch 81/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.4258 - mae: 16.9144
# Epoch 82/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.1388 - mae: 16.6270
# Epoch 83/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.0348 - mae: 16.5232
# Epoch 84/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.2620 - mae: 16.7515
# Epoch 85/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.1510 - mae: 16.6408
# Epoch 86/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.2636 - mae: 16.7538
# Epoch 87/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.2854 - mae: 16.7755
# Epoch 88/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.3406 - mae: 16.8299
# Epoch 89/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.1476 - mae: 16.6355
# Epoch 90/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.2158 - mae: 16.7034
# Epoch 91/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.3090 - mae: 16.7987
# Epoch 92/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.3260 - mae: 16.8151
# Epoch 93/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.0635 - mae: 16.5537
# Epoch 94/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.1770 - mae: 16.6647
# Epoch 95/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.2279 - mae: 16.7178
# Epoch 96/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.1742 - mae: 16.6636
# Epoch 97/200
# 46/46 [==============================] - 1s 27ms/step - loss: 15.9047 - mae: 16.3953
# Epoch 98/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.2721 - mae: 16.7619
# Epoch 99/200
# 46/46 [==============================] - 1s 27ms/step - loss: 16.5340 - mae: 17.0239
# Epoch 100/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.0867 - mae: 16.5770
# Epoch 101/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.6195 - mae: 17.1077
# Epoch 102/200
# 46/46 [==============================] - 2s 33ms/step - loss: 16.5747 - mae: 17.0665
# Epoch 103/200
# 46/46 [==============================] - 1s 30ms/step - loss: 16.1999 - mae: 16.6894
# Epoch 104/200
# 46/46 [==============================] - 1s 30ms/step - loss: 16.1330 - mae: 16.6232
# Epoch 105/200
# 46/46 [==============================] - 1s 30ms/step - loss: 16.0245 - mae: 16.5125
# Epoch 106/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.0860 - mae: 16.5747
# Epoch 107/200
# 46/46 [==============================] - 1s 29ms/step - loss: 16.0941 - mae: 16.5837
# Epoch 108/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.9939 - mae: 16.4840
# Epoch 109/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.9108 - mae: 16.4011
# Epoch 110/200
# 46/46 [==============================] - 1s 29ms/step - loss: 16.3410 - mae: 16.8321
# Epoch 111/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.3723 - mae: 16.8627
# Epoch 112/200
# 46/46 [==============================] - 1s 29ms/step - loss: 16.4683 - mae: 16.9578
# Epoch 113/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.9557 - mae: 16.4450
# Epoch 114/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.8896 - mae: 16.3791
# Epoch 115/200
# 46/46 [==============================] - 1s 29ms/step - loss: 16.1013 - mae: 16.5902
# Epoch 116/200
# 46/46 [==============================] - 1s 29ms/step - loss: 16.4096 - mae: 16.9006
# Epoch 117/200
# 46/46 [==============================] - 1s 29ms/step - loss: 16.1015 - mae: 16.5912
# Epoch 118/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.9486 - mae: 16.4394
# Epoch 119/200
# 46/46 [==============================] - 1s 29ms/step - loss: 16.0160 - mae: 16.5042
# Epoch 120/200
# 46/46 [==============================] - 1s 29ms/step - loss: 16.1699 - mae: 16.6610
# Epoch 121/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.0829 - mae: 16.5721
# Epoch 122/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.8687 - mae: 16.3583
# Epoch 123/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.9011 - mae: 16.3897
# Epoch 124/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.9382 - mae: 16.4266
# Epoch 125/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.1071 - mae: 16.5948
# Epoch 126/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.9000 - mae: 16.3901
# Epoch 127/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.9480 - mae: 16.4379
# Epoch 128/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.2042 - mae: 16.6928
# Epoch 129/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.0136 - mae: 16.5014
# Epoch 130/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.9119 - mae: 16.4026
# Epoch 131/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.8833 - mae: 16.3711
# Epoch 132/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.8523 - mae: 16.3413
# Epoch 133/200
# 46/46 [==============================] - 1s 29ms/step - loss: 16.0842 - mae: 16.5720
# Epoch 134/200
# 46/46 [==============================] - 1s 29ms/step - loss: 16.3919 - mae: 16.8802
# Epoch 135/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.8622 - mae: 16.3506
# Epoch 136/200
# 46/46 [==============================] - 1s 29ms/step - loss: 16.1119 - mae: 16.6007
# Epoch 137/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.9385 - mae: 16.4274
# Epoch 138/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.7398 - mae: 16.2278
# Epoch 139/200
# 46/46 [==============================] - 1s 29ms/step - loss: 16.0186 - mae: 16.5079
# Epoch 140/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.8295 - mae: 16.3180
# Epoch 141/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.6939 - mae: 16.1831
# Epoch 142/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.7653 - mae: 16.2542
# Epoch 143/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.8150 - mae: 16.3044
# Epoch 144/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.7728 - mae: 16.2618
# Epoch 145/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.7253 - mae: 16.2133
# Epoch 146/200
# 46/46 [==============================] - 1s 28ms/step - loss: 16.0180 - mae: 16.5076
# Epoch 147/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.7415 - mae: 16.2301
# Epoch 148/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.9816 - mae: 16.4698
# Epoch 149/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.7242 - mae: 16.2126
# Epoch 150/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.7128 - mae: 16.2026
# Epoch 151/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.9663 - mae: 16.4568
# Epoch 152/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.5901 - mae: 16.0794
# Epoch 153/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.6391 - mae: 16.1294
# Epoch 154/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.8070 - mae: 16.2953
# Epoch 155/200
# 46/46 [==============================] - 1s 30ms/step - loss: 16.0300 - mae: 16.5191
# Epoch 156/200
# 46/46 [==============================] - 1s 29ms/step - loss: 16.1379 - mae: 16.6265
# Epoch 157/200
# 46/46 [==============================] - 1s 29ms/step - loss: 16.1059 - mae: 16.5932
# Epoch 158/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.9124 - mae: 16.4011
# Epoch 159/200
# 46/46 [==============================] - 1s 30ms/step - loss: 15.8894 - mae: 16.3778
# Epoch 160/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.5101 - mae: 15.9977
# Epoch 161/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.5753 - mae: 16.0635
# Epoch 162/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.5361 - mae: 16.0243
# Epoch 163/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.5963 - mae: 16.0848
# Epoch 164/200
# 46/46 [==============================] - 1s 29ms/step - loss: 16.0745 - mae: 16.5644
# Epoch 165/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.8429 - mae: 16.3327
# Epoch 166/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.5531 - mae: 16.0419
# Epoch 167/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.8276 - mae: 16.3148
# Epoch 168/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.5667 - mae: 16.0559
# Epoch 169/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.8160 - mae: 16.3047
# Epoch 170/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.4947 - mae: 15.9824
# Epoch 171/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.6501 - mae: 16.1386
# Epoch 172/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.5173 - mae: 16.0060
# Epoch 173/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.4464 - mae: 15.9347
# Epoch 174/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.4967 - mae: 15.9843
# Epoch 175/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.9945 - mae: 16.4852
# Epoch 176/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.5123 - mae: 16.0008
# Epoch 177/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.6856 - mae: 16.1744
# Epoch 178/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.7481 - mae: 16.2363
# Epoch 179/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.4853 - mae: 15.9732
# Epoch 180/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.4688 - mae: 15.9564
# Epoch 181/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.4707 - mae: 15.9601
# Epoch 182/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.8682 - mae: 16.3566
# Epoch 183/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.4044 - mae: 15.8911
# Epoch 184/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.5473 - mae: 16.0333
# Epoch 185/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.7299 - mae: 16.2204
# Epoch 186/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.9510 - mae: 16.4417
# Epoch 187/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.6064 - mae: 16.0931
# Epoch 188/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.6295 - mae: 16.1171
# Epoch 189/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.7607 - mae: 16.2485
# Epoch 190/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.3994 - mae: 15.8873
# Epoch 191/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.6395 - mae: 16.1283
# Epoch 192/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.8226 - mae: 16.3117
# Epoch 193/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.6382 - mae: 16.1281
# Epoch 194/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.5578 - mae: 16.0456
# Epoch 195/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.3820 - mae: 15.8691
# Epoch 196/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.4646 - mae: 15.9511
# Epoch 197/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.5246 - mae: 16.0133
# Epoch 198/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.5318 - mae: 16.0211
# Epoch 199/200
# 46/46 [==============================] - 1s 28ms/step - loss: 15.4780 - mae: 15.9662
# Epoch 200/200
# 46/46 [==============================] - 1s 29ms/step - loss: 15.3873 - mae: 15.8763

# %%
# Tensorflow面板弹出
# %load_ext tensorboard
# %reload_ext tensorboard
# %tensorboard --logdir logs/fit
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 14412), started 0:01:12 ago. (Use '!kill 14412' to kill it.)
#       <iframe id="tensorboard-frame-addfe7cce9d3921a" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-addfe7cce9d3921a");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# Fetch the MAE and Huber Loss from the history
mae=history.history['mae']
loss=history.history['loss']

# Plot MAE and Huber Loss
fig = plt.figure(figsize=(15, 6))
plt.plot(mae, 'r')
plt.plot(loss, 'b')
plt.title('MAE and Loss')
plt.xlabel("Epochs")
plt.legend(["MAE", "Loss"])

# %%
# Call the model_forecast here and display the plots of validation and prediction
rnn_forecast = model_forecast(model, series[:, np.newaxis], window_size)
rnn_forecast = rnn_forecast[split_time - window_size:-1, 0]  # rnn_forecast[-328:-1, 0]

# Plots
plt.figure(figsize=(15, 6))
plt.plot(time_valid, x_valid)
plt.plot(time_valid, rnn_forecast)
plt.title("")
plt.legend(["Validation Data", "Predicted Data"])
plt.show()
# Out:
# 52/52 [==============================] - 1s 16ms/step

# %%
# Validation MAE
val_mae=tf.keras.metrics.mae(x_valid, rnn_forecast).numpy()
print(f"MAE on the validation data:- {val_mae}")
# Out:
# MAE on the validation data:- 15.050354957580566

# %% [markdown]
# ## 结果展示

# %%
# %% [markdown]
# ## 结果展示

# %%
# 1. 确保模型已经训练好，对整个序列进行预测
full_forecast = model_forecast(model, series[:, np.newaxis], window_size)   # shape: (len(series)-window_size, 1)
full_forecast = full_forecast[:, 0]   # 变成一维

# 2. 计算原始数据中 2024-01 和 2026-04 的索引
data['date'] = pd.to_datetime(data[['year', 'month']].assign(day=1))
start_date = pd.Timestamp('2024-01-01')
end_date   = pd.Timestamp('2026-04-01')
start_idx = data[data['date'] == start_date].index[0]
end_idx   = data[data['date'] == end_date].index[0]

# 3. 预测值的索引偏移
forecast_start = start_idx - window_size
forecast_end   = end_idx - window_size

# 检查索引是否有效
if forecast_start < 0 or forecast_end >= len(full_forecast):
    raise ValueError(f"索引超出范围: forecast_start={forecast_start}, forecast_end={forecast_end}, full_forecast长度={len(full_forecast)}")

# 4. 正确截取 2024-2026 的真实值与预测值（此时变量正式被定义和赋值！）
y_true_2024_2026 = data['sunspot_number'].iloc[start_idx:end_idx+1].values
y_pred_2024_2026 = full_forecast[forecast_start:forecast_end+1]

# 5. 【移到这里】检查模型预测值是否恒定
print("预测的唯一值有：", np.unique(y_pred_2024_2026)) 

# 6. 可视化
plt.figure(figsize=(12,5))
plt.plot(y_true_2024_2026, label='Actual')
plt.plot(y_pred_2024_2026, label='Predicted')
plt.legend()
plt.title('Sunspots: 2024-01 to 2026-04')
plt.show()

# 7. 计算标量 MAE 和 MSE
y_true_flat = y_true_2024_2026.flatten()
y_pred_flat = y_pred_2024_2026.flatten()

mae_scalar = np.mean(np.abs(y_true_flat - y_pred_flat))
mse_scalar = np.mean((y_true_flat - y_pred_flat) ** 2)

print(f"MAE (2024-2026): {mae_scalar:.4f}")
print(f"MSE (2024-2026): {mse_scalar:.4f}")
# Out:
# 52/52 [==============================] - 1s 15ms/step
# 预测的唯一值有： [103.137375 110.034004 117.231926 118.22745  122.46835  127.80084
#  129.05157  132.34598  132.76436  133.47438  133.64815  138.59277
#  139.95636  141.5414   142.7379   143.99123  144.63896  146.53677
#  149.4378   151.86261  152.93533  154.68     155.00824  155.31296
#  156.81215  159.7453   162.04602  164.00151 ]
# MAE (2024-2026): 21.0198
# MSE (2024-2026): 771.9555
